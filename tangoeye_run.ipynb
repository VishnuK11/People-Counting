# %% [markdown]
# ## Instructions
#
# 1.   Run the following blocks of code.
# 2.   Restart after installing requirements.
# 3. Download weights file from link: 'https://drive.google.com/file/d/1lLiJgaTa_LAW7iezngl6IWvMaKAC7e5x/view?usp=sharing' and paste in  ./data/yolov4.weights
# 3.  Run the code block below and outputs will be available in folder ./outputs

# %%
# !git clone https://github.com/VishnuK11/People-Counting
# Out:
# fatal: destination path 'People-Counting' already exists and is not an empty directory.

# %%
# %cd People-Counting
# Out:
# /content/People-Counting

# %%
# !pip install -r requirements-gpu.txt

# %% [markdown]
# * Restart Runtime after udpate installations

# %% [markdown]
# * Download weights from link provided

# %%
# %cd ..

# from google.colab import drive
# drive.mount("/content/drive")
# Out:
# /content
# Mounted at /content/drive

# %%
# %cd ./People-Counting/
# !cp ../drive/MyDrive/TangoEye_submission/yolov4.weights ./data
# Out:
# /content/People-Counting

# %%
# !python save_model.py --model yolov4
# Out:
# 2021-03-28 19:45:59.622084: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-28 19:46:00.760718: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-03-28 19:46:00.774765: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-28 19:46:00.775367: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-03-28 19:46:00.775404: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python object_tracker.py --video ./data/video/test.mp4 --output ./outputs/output_0.avi --model yolov4 --dont_show True
# Out:
# Frame #:  1
# Total Left Moves: 0
# Total Right Moves: 0
# FPS: 0.49
# Total Time: 2.05. GPU: 1.81.
# Frame #:  2
# Total Left Moves: 0
# Total Right Moves: 0
# FPS: 12.89
# Total Time: 0.08. GPU: 0.03.
# Frame #:  3
# Total Left Moves: 0
# Total Right Moves: 0
# FPS: 13.97
# Total Time: 0.07. GPU: 0.03.
# Frame #:  4
# Total Left Moves: 0
# Total Right Moves: 0
# FPS: 13.21
# Total Time: 0.08. GPU: 0.03.
# Frame #:  5
# Total Left Moves: 0
# Total Right Moves: 1
# FPS: 13.05
# Total Time: 0.08. GPU: 0.03.
# Frame #:  6
# Total Left Moves: 2
# Total Right Moves: 5
# FPS: 12.16
# Total Time: 0.08. GPU: 0.03.
# Frame #:  7
# Total Left Moves: 2
# Total Right Moves: 6
# FPS: 13.51
# Total Time: 0.07. GPU: 0.03.
# Frame #:  8
# Total Left Moves: 2
# Total Right Moves: 6
# FPS: 12.58
# Total Time: 0.08. GPU: 0.03.
# Frame #:  9
# Total Left Moves: 2
# Total Right Moves: 7
# FPS: 12.82
# Total Time: 0.08. GPU: 0.03.
# Frame #:  10
# Total Left Moves: 2
# Total Right Moves: 7
# FPS: 12.03
# ...

# %%
# !python object_tracker.py --video ./data/video/VideoFeed.mp4 --output ./outputs/output_1.avi --model yolov4 --dont_show True
# Out:
# Frame #:  1
# Total Left Moves: 0
# Total Right Moves: 0
# FPS: 0.50
# Total Time: 2.01. GPU: 1.81.
# Frame #:  2
# Total Left Moves: 0
# Total Right Moves: 0
# FPS: 17.91
# Total Time: 0.06. GPU: 0.03.
# Frame #:  3
# Total Left Moves: 0
# Total Right Moves: 0
# FPS: 18.96
# Total Time: 0.05. GPU: 0.03.
# Frame #:  4
# Total Left Moves: 1
# Total Right Moves: 1
# FPS: 17.16
# Total Time: 0.06. GPU: 0.03.
# Frame #:  5
# Total Left Moves: 1
# Total Right Moves: 1
# FPS: 17.07
# Total Time: 0.06. GPU: 0.03.
# Frame #:  6
# Total Left Moves: 1
# Total Right Moves: 1
# FPS: 18.30
# Total Time: 0.05. GPU: 0.03.
# Frame #:  7
# Total Left Moves: 1
# Total Right Moves: 1
# FPS: 16.54
# Total Time: 0.06. GPU: 0.03.
# Frame #:  8
# Total Left Moves: 1
# Total Right Moves: 1
# FPS: 15.92
# Total Time: 0.06. GPU: 0.03.
# Frame #:  9
# Total Left Moves: 1
# Total Right Moves: 1
# FPS: 17.52
# Total Time: 0.06. GPU: 0.03.
# Frame #:  10
# Total Left Moves: 1
# Total Right Moves: 1
# FPS: 17.53
# ...

# %%
# !python object_tracker.py --video ./data/video/VideoFeed2.mp4 --output ./outputs/output_2.avi --model yolov4 --dont_show True
# Out:
# Streaming output truncated to the last 5000 lines.
# Total Left Moves: 4
# Total Right Moves: 5
# FPS: 20.89
# Total Time: 0.05. GPU: 0.03.
# Frame #:  95
# Total Left Moves: 4
# Total Right Moves: 5
# FPS: 19.89
# Total Time: 0.05. GPU: 0.03.
# Frame #:  96
# Total Left Moves: 4
# Total Right Moves: 5
# FPS: 18.68
# Total Time: 0.05. GPU: 0.03.
# Frame #:  97
# Total Left Moves: 5
# Total Right Moves: 5
# FPS: 18.61
# Total Time: 0.05. GPU: 0.03.
# Frame #:  98
# Total Left Moves: 5
# Total Right Moves: 5
# FPS: 20.16
# Total Time: 0.05. GPU: 0.03.
# Frame #:  99
# Total Left Moves: 5
# Total Right Moves: 5
# FPS: 18.46
# Total Time: 0.05. GPU: 0.03.
# Frame #:  100
# Total Left Moves: 5
# Total Right Moves: 5
# FPS: 19.52
# Total Time: 0.05. GPU: 0.03.
# Frame #:  101
# Total Left Moves: 4
# Total Right Moves: 5
# FPS: 17.99
# Total Time: 0.06. GPU: 0.03.
# Frame #:  102
# Total Left Moves: 4
# Total Right Moves: 5
# FPS: 18.25
# Total Time: 0.05. GPU: 0.03.
# Frame #:  103
# ...

# %%
# !python object_tracker.py --video ./data/video/VideoFeed3.mp4 --output ./outputs/output_3.avi --model yolov4 --dont_show True
# Out:
# Frame #:  1
# Total Left Moves: 0
# Total Right Moves: 0
# FPS: 0.50
# Total Time: 2.00. GPU: 1.77.
# Frame #:  2
# Total Left Moves: 0
# Total Right Moves: 0
# FPS: 10.88
# Total Time: 0.09. GPU: 0.03.
# Frame #:  3
# Total Left Moves: 0
# Total Right Moves: 0
# FPS: 11.27
# Total Time: 0.09. GPU: 0.03.
# Frame #:  4
# Total Left Moves: 0
# Total Right Moves: 0
# FPS: 11.49
# Total Time: 0.09. GPU: 0.03.
# Frame #:  5
# Total Left Moves: 1
# Total Right Moves: 0
# FPS: 10.97
# Total Time: 0.09. GPU: 0.03.
# Frame #:  6
# Total Left Moves: 1
# Total Right Moves: 2
# FPS: 11.21
# Total Time: 0.09. GPU: 0.03.
# Frame #:  7
# Total Left Moves: 1
# Total Right Moves: 4
# FPS: 10.71
# Total Time: 0.09. GPU: 0.03.
# Frame #:  8
# Total Left Moves: 1
# Total Right Moves: 3
# FPS: 11.09
# Total Time: 0.09. GPU: 0.03.
# Frame #:  9
# Total Left Moves: 1
# Total Right Moves: 4
# FPS: 10.83
# Total Time: 0.09. GPU: 0.03.
# Frame #:  10
# Total Left Moves: 2
# Total Right Moves: 4
# FPS: 11.16
# ...

# %%
# !dir ./data/video
# Out:
# test.mp4  VideoFeed2.mp4  VideoFeed3.mp4  VideoFeed.mp4  VideoFeed_short.mp4

# %%
from google.colab import files
files.download('./outputs/output_0.avi')
# files.download('./outputs/output_1.avi')
# files.download('./outputs/output_2.avi')
# files.download('./outputs/output_3.avi')

# %%
# !git pull 'https://github.com/VishnuK11/People-Counting'
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/VishnuK11/People-Counting
#  * branch            HEAD       -> FETCH_HEAD
# Updating a4b92f2..e9672b6
# Fast-forward
#  deep_sort/tracker.py | 6 +++---
#  1 file changed, 3 insertions(+), 3 deletions(-)
